# %% [markdown]
# --- Day 5: Supply Stacks ---
# The expedition can depart as soon as the final supplies have been unloaded from the ships. Supplies are stored in stacks of marked crates, but because the needed supplies are buried under many other crates, the crates need to be rearranged.
#
# The ship has a giant cargo crane capable of moving crates between stacks. To ensure none of the crates get crushed or fall over, the crane operator will rearrange them in a series of carefully-planned steps. After the crates are rearranged, the desired crates will be at the top of each stack.
#
# The Elves don't want to interrupt the crane operator during this delicate procedure, but they forgot to ask her which crate will end up where, and they want to be ready to unload them as soon as possible so they can embark.
#
# They do, however, have a drawing of the starting stacks of crates and the rearrangement procedure (your puzzle input). For example:
#
#     [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
#
# move 1 from 2 to 1
# move 3 from 1 to 3
# move 2 from 2 to 1
# move 1 from 1 to 2
# In this example, there are three stacks of crates. Stack 1 contains two crates: crate Z is on the bottom, and crate N is on top. Stack 2 contains three crates; from bottom to top, they are crates M, C, and D. Finally, stack 3 contains a single crate, P.
#
# Then, the rearrangement procedure is given. In each step of the procedure, a quantity of crates is moved from one stack to a different stack. In the first step of the above rearrangement procedure, one crate is moved from stack 2 to stack 1, resulting in this configuration:
#
# [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
# In the second step, three crates are moved from stack 1 to stack 3. Crates are moved one at a time, so the first crate to be moved (D) ends up below the second and third crates:
#
#         [Z]
#         [N]
#     [C] [D]
#     [M] [P]
#  1   2   3
# Then, both crates are moved from stack 2 to stack 1. Again, because crates are moved one at a time, crate C ends up below crate M:
#
#         [Z]
#         [N]
# [M]     [D]
# [C]     [P]
#  1   2   3
# Finally, one crate is moved from stack 1 to stack 2:
#
#         [Z]
#         [N]
#         [D]
# [C] [M] [P]
#  1   2   3
# The Elves just need to know which crate will end up on top of each stack; in this example, the top crates are C in stack 1, M in stack 2, and Z in stack 3, so you should combine these together and give the Elves the message CMZ.
#
# After the rearrangement procedure completes, what crate ends up on top of each stack?

# %%
# I modified the file to make it a bit easier

with open("input.txt") as inF:
    instrs = inF.read().splitlines()

with open("input2.txt") as inF:
    instrs2 = inF.read().splitlines()


sampleInstrs = """move 1 from 2 to 1
move 3 from 1 to 3
move 2 from 2 to 1
move 1 from 1 to 2""".splitlines()

sampleInstrs2 = """    [D]    
[N] [C]    
[Z] [M] [P]
 1   2   3 """

sampleInstrs2 = sampleInstrs2.splitlines()

# %%
# get the number of columns
import re

numCols = 0

numCols = int(re.findall(r"\d+", instrs2[-1])[-1])

colsDict = {}

for col in range(1, numCols+1):
    colsDict[col] = []

# because of the pattern it makes (the columns have to line up, the max number of columns is 9)

for row in instrs2[:-1]:
    # print("*"*20)

    for ind in range(1, numCols+1):
        letter = row[instrs2[-1].index(str(ind))]
        # print("letter", ind, letter)
        if letter != ' ':
            colsDict[ind].append(letter.replace("[", "").replace("]",""))

    # print("*"*20)

# reverse the order (that way its append rather than push)

for col in colsDict:
    colsDict[col] = colsDict[col][::-1]

print(colsDict)
# Out:
# {1: ['H', 'R', 'B', 'D', 'Z', 'F', 'L', 'S'], 2: ['T', 'B', 'M', 'Z', 'R'], 3: ['Z', 'L', 'C', 'H', 'N', 'S'], 4: ['S', 'C', 'F', 'J'], 5: ['P', 'G', 'H', 'W', 'R', 'Z', 'B'], 6: ['V', 'J', 'Z', 'G', 'D', 'N', 'M', 'T'], 7: ['G', 'L', 'N', 'W', 'F', 'S', 'P', 'Q'], 8: ['M', 'Z', 'R'], 9: ['M', 'C', 'L', 'G', 'V', 'R', 'T']}

# %%
from copy import deepcopy
updatedDict = deepcopy(colsDict)

# for col in colsDict:
#     print(col, colsDict[col])


for instr in instrs:
    print("*"*20)
    print(instr)

    for col in updatedDict:
        print(col, updatedDict[col])

    numItems, moveFrom, moveTo = map(int, re.findall(r"\d+", instr))

    itemsToMove = [updatedDict[moveFrom].pop() for _ in range(numItems)]

    # reverse items to move
    print(itemsToMove)

    # updatedDict[moveFrom] = updatedDict[moveFrom][:-numItems]
    # print(updatedDict[moveFrom])
    updatedDict[moveTo].extend(itemsToMove)
    # print(updatedDict[moveTo])

    for col in updatedDict:
        print(col, updatedDict[col])

    print("*"*20)
    # break
    #pass

answ = ""
for col in updatedDict:
    answ += updatedDict[col][-1]

print(answ)
# Out:
# ********************
# move 6 from 1 to 7
# 1 ['H', 'R', 'B', 'D', 'Z', 'F', 'L', 'S']
# 2 ['T', 'B', 'M', 'Z', 'R']
# 3 ['Z', 'L', 'C', 'H', 'N', 'S']
# 4 ['S', 'C', 'F', 'J']
# 5 ['P', 'G', 'H', 'W', 'R', 'Z', 'B']
# 6 ['V', 'J', 'Z', 'G', 'D', 'N', 'M', 'T']
# 7 ['G', 'L', 'N', 'W', 'F', 'S', 'P', 'Q']
# 8 ['M', 'Z', 'R']
# 9 ['M', 'C', 'L', 'G', 'V', 'R', 'T']
# ['S', 'L', 'F', 'Z', 'D', 'B']
# 1 ['H', 'R']
# 2 ['T', 'B', 'M', 'Z', 'R']
# 3 ['Z', 'L', 'C', 'H', 'N', 'S']
# 4 ['S', 'C', 'F', 'J']
# 5 ['P', 'G', 'H', 'W', 'R', 'Z', 'B']
# 6 ['V', 'J', 'Z', 'G', 'D', 'N', 'M', 'T']
# 7 ['G', 'L', 'N', 'W', 'F', 'S', 'P', 'Q', 'S', 'L', 'F', 'Z', 'D', 'B']
# 8 ['M', 'Z', 'R']
# 9 ['M', 'C', 'L', 'G', 'V', 'R', 'T']
# ********************
# ********************
# move 2 from 2 to 4
# 1 ['H', 'R']
# 2 ['T', 'B', 'M', 'Z', 'R']
# 3 ['Z', 'L', 'C', 'H', 'N', 'S']
# 4 ['S', 'C', 'F', 'J']
# 5 ['P', 'G', 'H', 'W', 'R', 'Z', 'B']
# 6 ['V', 'J', 'Z', 'G', 'D', 'N', 'M', 'T']
# ...

# %%
# part2

from copy import deepcopy
updatedDict = deepcopy(colsDict)

# for col in colsDict:
#     print(col, colsDict[col])


for instr in instrs:
    print("*"*20)
    print(instr)

    for col in updatedDict:
        print(col, updatedDict[col])

    numItems, moveFrom, moveTo = map(int, re.findall(r"\d+", instr))

    itemsToMove = list(updatedDict[moveFrom][-numItems:])
    #[updatedDict[moveFrom].pop() for _ in range(numItems)]

    # reverse items to move
    print(itemsToMove)

    updatedDict[moveFrom] = updatedDict[moveFrom][:-numItems]
    # print(updatedDict[moveFrom])
    updatedDict[moveTo].extend(itemsToMove)
    # print(updatedDict[moveTo])

    for col in updatedDict:
        print(col, updatedDict[col])

    print("*"*20)
    # break
    #pass

answ = ""
for col in updatedDict:
    answ += updatedDict[col][-1]

print(answ)
# Out:
# ********************
# move 6 from 1 to 7
# 1 ['H', 'R', 'B', 'D', 'Z', 'F', 'L', 'S']
# 2 ['T', 'B', 'M', 'Z', 'R']
# 3 ['Z', 'L', 'C', 'H', 'N', 'S']
# 4 ['S', 'C', 'F', 'J']
# 5 ['P', 'G', 'H', 'W', 'R', 'Z', 'B']
# 6 ['V', 'J', 'Z', 'G', 'D', 'N', 'M', 'T']
# 7 ['G', 'L', 'N', 'W', 'F', 'S', 'P', 'Q']
# 8 ['M', 'Z', 'R']
# 9 ['M', 'C', 'L', 'G', 'V', 'R', 'T']
# ['B', 'D', 'Z', 'F', 'L', 'S']
# 1 ['H', 'R']
# 2 ['T', 'B', 'M', 'Z', 'R']
# 3 ['Z', 'L', 'C', 'H', 'N', 'S']
# 4 ['S', 'C', 'F', 'J']
# 5 ['P', 'G', 'H', 'W', 'R', 'Z', 'B']
# 6 ['V', 'J', 'Z', 'G', 'D', 'N', 'M', 'T']
# 7 ['G', 'L', 'N', 'W', 'F', 'S', 'P', 'Q', 'B', 'D', 'Z', 'F', 'L', 'S']
# 8 ['M', 'Z', 'R']
# 9 ['M', 'C', 'L', 'G', 'V', 'R', 'T']
# ********************
# ********************
# move 2 from 2 to 4
# 1 ['H', 'R']
# 2 ['T', 'B', 'M', 'Z', 'R']
# 3 ['Z', 'L', 'C', 'H', 'N', 'S']
# 4 ['S', 'C', 'F', 'J']
# 5 ['P', 'G', 'H', 'W', 'R', 'Z', 'B']
# 6 ['V', 'J', 'Z', 'G', 'D', 'N', 'M', 'T']
# ...
